# %% [markdown]
# # **DevelopersHub Corporation**
#
# **Data Science &amp; Analytics Internship Tasks**

# %% [markdown]
# ## **Task 1: Exploring and Visualizing a Simple Dataset**
#
# ● Load the dataset using the pandas library.
#
# ● Display dataset structure using .shape, .columns, and .head().
#
# ● Create basic visualizations:
#
#       ○ Scatter plot to analyze relationships between variables.
#
#       ○ Histogram to examine data distribution.
#
#       ○ Box plot to detect outliers and spread of values.

# %% [markdown]
# # Dataset : Iris Dataset
#
# The Iris dataset was used in R.A. Fisher's classic 1936 paper, The Use of Multiple Measurements in Taxonomic Problems, and can also be found on the UCI Machine Learning Repository.
#
# It includes three iris species with 50 samples each as well as some properties about each flower. One flower species is linearly separable from the other two, but the other two are not linearly separable from each other.
#
# The columns in this dataset are:
#
# Id
#
# SepalLengthCm
#
# SepalWidthCm
#
# PetalLengthCm
#
# PetalWidthCm
#
# Species

# %%
#import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#get information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
#generate descriptive statistics
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
#scatter plot
df.plot(kind='scatter', x='SepalLengthCm', y='SepalWidthCm')
df.plot(kind='scatter', x='PetalLengthCm', y='PetalWidthCm')
df.plot(kind='scatter', x='SepalLengthCm', y='PetalLengthCm')
df.plot(kind='scatter', x='SepalLengthCm', y='PetalWidthCm')
df.plot(  kind='scatter', x='SepalWidthCm', y='PetalLengthCm')
df.plot(kind='scatter', x='SepalWidthCm', y='PetalWidthCm')
# Out:
# <Axes: xlabel='SepalWidthCm', ylabel='PetalWidthCm'>

# %% [markdown]
# # Conclusion :
#
# **SepalLengthCm vs SepalWidthCm** – Weak correlation, points are widely scattered; some overlap between species.
#
# **PetalLengthCm vs PetalWidthCm** – Strong positive correlation; clear species separation, especially Iris setosa.
#
# **SepalLengthCm vs PetalLengthCm** – Moderate positive correlation; setosa clearly apart, others overlap slightly.
#
# **SepalLengthCm vs PetalWidthCm** – Positive trend; setosa well-separated, versicolor and virginica closer.
#
# **SepalWidthCm vs PetalLengthCm** – Weak to moderate correlation; clear distinction for setosa, overlap for others.
#
# **SepalWidthCm vs PetalWidthCm** – Weak correlation; setosa separate, but versicolor and virginica mix.

# %%
#histogram
df.hist(bins=50, figsize=(12,10))
# Out:
# array([[<Axes: title={'center': 'Id'}>,
#         <Axes: title={'center': 'SepalLengthCm'}>],
#        [<Axes: title={'center': 'SepalWidthCm'}>,
#         <Axes: title={'center': 'PetalLengthCm'}>],
#        [<Axes: title={'center': 'PetalWidthCm'}>, <Axes: >]], dtype=object)

# %% [markdown]
# # Conclusion :
#
# **Id** – Uniform distribution, as IDs are evenly spaced from 1 to 150.
#
# **SepalLengthCm** – Roughly normal distribution, slightly right-skewed; most values between 5.0–6.5 cm.
#
# **SepalWidthCm** – Slightly left-skewed; most flowers have sepal widths between 2.8–3.4 cm.
#
# **PetalLengthCm** – Bimodal distribution; one cluster around 1.5 cm (setosa) and another between 4–5.5 cm (other species).
#
# **PetalWidthCm** – Bimodal distribution; one cluster near 0.2 cm (setosa) and another between 1.2–2.0 cm (other species).

# %%
sns.boxplot(x='Species', y='SepalLengthCm', data=df)
# Out:
# <Axes: xlabel='Species', ylabel='SepalLengthCm'>

# %% [markdown]
# # Conslusion :
#
# The boxplot shows that Iris-virginica has the largest median sepal length, followed by Iris-versicolor and then Iris-setosa. Setosa has the smallest range, while Virginica has the widest variation with a slight outlier.
